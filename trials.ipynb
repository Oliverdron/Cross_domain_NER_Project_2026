# %%
import numpy as np
import pandas as pd
from helper.helper_funcs import parse_iob2, jaccard_vocab

# %%
ewt_train   = parse_iob2("data_iob2/universal_train.iob2")
conll_train = parse_iob2("data_iob2/news_train.iob2")
wiesp_train = parse_iob2("data_iob2/astro_train.iob2")

print(jaccard_vocab(ewt_train, conll_train))  # expect ~0.35–0.45
print(jaccard_vocab(ewt_train, wiesp_train))  # expect ~0.08–0.15
# Out:
# 0.007088824396974166
# 0.003017382748442112
